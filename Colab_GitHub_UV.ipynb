# %% [markdown]
# # 🚀 PX4 AI Classifier: Professional GitHub + UV Training
# This notebook uses **GitHub** for code and **uv** for the fastest possible dependency setup.

# %% [markdown]
# ### 1️⃣ Clone Repository & Setup UV
# This cell clones your code and installs the ultra-fast `uv` package manager.

# %%
# 1. Clone your repo (REPLACE with your URL)
# !git clone https://github.com/abdelhadi-osama/px4_ai_classifier.git
# %cd px4-ai-classifier

# 2. Install UV
# !curl -LsSf https://astral.sh/uv/install.sh | sh
import os
os.environ['PATH'] = f"{os.environ['PATH']}:/root/.local/bin"
# Out:
# Cloning into 'px4_ai_classifier'...
# remote: Enumerating objects: 14604, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 14604 (delta 7), reused 51 (delta 5), pack-reused 14551 (from 2)
# Receiving objects: 100% (14604/14604), 110.08 MiB | 14.43 MiB/s, done.
# Resolving deltas: 100% (3371/3371), done.
# [Errno 2] No such file or directory: 'px4-ai-classifier'
# /content
# downloading uv 0.11.19 x86_64-unknown-linux-gnu
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %% [markdown]
# ### 2️⃣ Sync Dependencies (Fast!)
# Uses `uv` to install everything from your `pyproject.toml` in seconds.

# %%
# !cd px4_ai_classifier && python -m pip install uv
# Out:
# /bin/bash: line 1: !python: command not found

# %%
# !cd px4_ai_classifier && ls && uv sync
# !pwd
# Out:
# px4_ai_classifier  sample_data
# Colab_Training.ipynb  main.py		  pyproject.toml  src	 uv.lock
# data		      PROJECT_JOURNAL.md  README.md	  tests
# /bin/bash: line 1: !uv: command not found
# /content

# %%
# !uv --version
# Out:
# uv 0.11.19 (x86_64-unknown-linux-gnu)

# %% [markdown]
# ### 3️⃣ START TRAINING
# Runs the professional training script.

# %%
# !export PYTHONPATH=$PYTHONPATH:. && python3 src/train.py

# %% [markdown]
# ### 4️⃣ DOWNLOAD RESULTS

# %%
from google.colab import files
import os
# !zip -r training_results.zip best_*.pt *.png
if os.path.exists('training_results.zip'):
  files.download('training_results.zip')
